# %%
from pathlib import Path
from collections import defaultdict, Counter
import numpy as np
from conlleval import evaluate
from scipy.optimize import fmin_l_bfgs_b
import json


def read_data(path, column=0):
    """column=0 means input sequence, column=1 means label
    """
    with open(path) as f:
        lines = f.readlines()
    
    data = []
    sample = []
    
    for line in lines:
        formatted_line = line.strip()
        
        if len(formatted_line) > 0:
            split_data = formatted_line.split(" ")
            sample.append(split_data[column])

        else:
            data.append(sample)
            sample = []
            
    return data


def calc_e(x_data, y_data, x_vocab, y_vocab):
    count_emission = Counter([(x,y) for x_instance, y_instance in zip(x_data, y_data) for x, y in zip(x_instance, y_instance)])
    count_label = Counter([oo for o in y_data for oo in o])
    
    e_score = {}
    for y in y_vocab:
        for x in x_vocab:
            feature = f"emission:{y}+{x}"
            
            if (x,y) not in count_emission:
                e_score[feature] = ninf
            else:
                score = np.log(count_emission[(x,y)]  /  count_label[y])
                e_score[feature] = score
    
    return e_score

def calc_t(y_data, y_vocab):
    count_transition = Counter([ (y_prev, y) for y_instance in y_data for y_prev, y in zip(['START'] + y_instance, y_instance + ['STOP'])])
    count_label = Counter([y for y_instance in y_data for y in ['START'] + y_instance])
    
    f_score = {}
    for y_prev in ['START'] + y_vocab:
        for y in y_vocab + ['STOP']:
            feature = f"transition:{y_prev}+{y}"
            
            if (y_prev,y) not in count_transition:
                f_score[feature] = ninf
            else:
                score = np.log(count_transition[(y_prev,y)]  /  count_label[y_prev])
                f_score[feature] = score
    
    return f_score

def calc_new(x_data, y_data, x_vocab, y_vocab):
    count_numerator = []
    for x_instance, y_instance in zip(x_data, y_data):
        for x, y_prev, y in zip(x_instance, ['START'] + y_instance[:-1], y_instance):
            count_numerator.append( (y_prev, y, x) )
    count_numerator = Counter(count_numerator)
    count_denom = Counter([ y for y_instance in y_data for y in ['START'] + y_instance[:-1] ])
    
    f_score = {}
    for y_prev in ['START'] + y_vocab:
        for y in y_vocab:
            for x in x_vocab:
                feature = f"transition:{y_prev}+{y}+{x}"
                if (y_prev, y, x) not in count_numerator:
                    f_score[feature] = ninf
                else:
                    f_score[feature] = np.log(count_numerator[(y_prev, y, x)] / count_denom[y_prev])
    
    return f_score


def compute_score(x_instance, x_instance_pos, y_instance, feature_dict):
    feature_count = defaultdict(int)
    
    for x, y in zip(x_instance, y_instance): feature_count[f"emission:{y}+{x}"] += 1
    for x, y in zip(x_instance_pos, y_instance): feature_count[f"emission:{y}+{x}"] += 1

    for y_prev, y in zip(['START'] + y_instance, y_instance + ['STOP']):
        feature_count[f"transition:{y_prev}+{y}"] += 1
    for y_prev, y, x in zip( ['START']+ y_instance[:-1], y_instance, x_instance ):
        feature_count[f"transition:{y_prev}+{y}+{x}"] += 1
    score = sum([feature_dict[feat]*count for feat, count in feature_count.items()])
    return score



def viterbi(x_instance, x_instance_pos, y_vocab, feature_dict):
    n, d = len(x_instance), len(y_vocab)
    scores = np.full( (n,d), -np.inf) # initialize to be very negative
    bp = np.full( (n,d), 0, dtype=np.int)
    
    for i, y in enumerate(y_vocab):
        t_score = feature_dict.get( f"transition:START+{y}",  ninf)
        e_score = feature_dict.get( f"emission:{y}+{x_instance[0]}",  ninf)
        e_score_pos = feature_dict.get(f"emission:{y}+{x_instance_pos[0]}", ninf)
        new_score = feature_dict.get(f"transition:START+{y}+{x_instance_pos[0]}", ninf)
        scores[0, i] = t_score + e_score + e_score_pos + new_score
        
    for i in range(1, n):
        for y_i, y in enumerate(y_vocab):
            for y_prev_i, y_prev in enumerate(y_vocab):
                t_score = feature_dict.get( f"transition:{y_prev}+{y}", ninf)
                e_score = feature_dict.get( f"emission:{y}+{x_instance[i]}", ninf)
                e_score_pos = feature_dict.get( f"emission:{y}+{x_instance_pos[i]}", ninf)
                new_score = feature_dict.get(f"transition:{y_prev}+{y}+{x_instance[i]}", ninf)
                score = t_score + e_score + e_score_pos + new_score + scores[i-1, y_prev_i]
                if score > scores[i, y_i]:
                    scores[i, y_i] = score
                    bp[i, y_i] = y_prev_i
    
    final_score, final_bp = ninf, 0
    for i, y_prev in enumerate(y_vocab):
        t_score = feature_dict.get( f"transition:{y_prev}+STOP", ninf)
        score = t_score + scores[n-1, i]
        if score > final_score: 
            final_score = score
            final_bp = i
    decoded_sequence = [ y_vocab[final_bp], ]
    for i in range(n-1, 0, -1):
        final_bp = bp[i, final_bp]
        decoded_sequence = [ y_vocab[final_bp] ] + decoded_sequence
        
    return decoded_sequence


def inference(in_file_path, y_vocab, feature_dict, out_file_path):
    x_data = read_data(in_file_path, column=0)
    x_data_pos = read_data(in_file_path, column=1)
    y_preds = []
    with open(out_file_path, 'w') as f:
        for x_instance, x_instance_pos in zip(x_data, x_data_pos):
            pred = viterbi(x_instance, x_instance_pos, y_vocab, feature_dict)
            y_preds.append(pred)
    return y_preds



def logsumexp(a):
    b = a.max()
    return  b + np.log( (np.exp(a-b)).sum() )

def forward(x_instance, x_instance_pos, y_vocab, feature_dict):
    n, d = len(x_instance), len(y_vocab)
    scores = np.zeros( (n,d) )
    
    for i, y in enumerate(y_vocab):
        t_score = feature_dict.get( f"transition:START+{y}", ninf)
        new_score = feature_dict.get( f"transition:START+{y}+{x_instance[0]}", ninf)
        scores[0, i] = t_score + new_score
    
    for i in range(1, n):
        for y_i, y in enumerate(y_vocab):
            temp = []
            for y_prev_i, y_prev in enumerate(y_vocab):
                t_score = feature_dict.get( f"transition:{y_prev}+{y}", ninf)
                e_score = feature_dict.get( f"emission:{y_prev}+{x_instance[i-1]}", ninf)
                e_score_pos = feature_dict.get( f"emission:{y_prev}+{x_instance_pos[i-1]}", ninf)
                new_score = feature_dict.get( f"transition:{y_prev}+{y}+{x_instance[i]}", ninf)
                temp.append(e_score + e_score_pos + t_score + new_score + scores[i-1, y_prev_i])
            scores[i, y_i] = logsumexp(np.array(temp))
    
    temp = []
    for i, y_prev in enumerate(y_vocab):
        t_score = feature_dict.get( f"transition:{y_prev}+STOP", ninf)
        e_score = feature_dict.get( f"emission:{y_prev}+{x_instance[-1]}", ninf)
        e_score_pos = feature_dict.get( f"emission:{y_prev}+{x_instance_pos[-1]}", ninf)
        temp.append(e_score + e_score_pos + t_score + scores[-1, i])
    alpha = logsumexp(np.array(temp))
    
    return scores, alpha



def loss_fn_instance(x_instance, x_instance_pos, y_instance, feature_dict, y_vocab):
    first_term = compute_score(x_instance, x_instance_pos, y_instance, feature_dict)
    _, forward_score = forward(x_instance, x_instance_pos, y_vocab, feature_dict)
    return forward_score - first_term


def backward(x_instance, x_instance_pos, y_vocab, feature_dict, aggreg_fn=logsumexp):
    n, d = len(x_instance), len(y_vocab)
    scores = np.zeros( (n,d) )
    
    for i, y in enumerate(y_vocab):
        t_score = feature_dict.get( f"transition:{y}+STOP", ninf)
        e_score = feature_dict.get( f"emission:{y}+{x_instance[-1]}", ninf)
        e_score_pos = feature_dict.get( f"emission:{y}+{x_instance_pos[-1]}", ninf) 
        scores[-1, i] = t_score + e_score + e_score_pos
        
    for i in range(n-1, 0, -1):
        for y_i, y in enumerate(y_vocab):
            temp = []
            for y_next_i, y_next in enumerate(y_vocab):
                t_score = feature_dict.get( f"transition:{y}+{y_next}", ninf)
                e_score = feature_dict.get( f"emission:{y}+{x_instance[i-1]}")
                e_score_pos = feature_dict.get( f"emission:{y}+{x_instance_pos[i-1]}", ninf) 
                new_score = feature_dict.get( f"transition:{y}+{y_next}+{x_instance[i]}", ninf)
                temp.append(e_score + e_score_pos + t_score + new_score + scores[i, y_next_i])
            scores[i-1, y_i] = aggreg_fn(np.array(temp))
            
    temp = []
    for i, y_next in enumerate(y_vocab):
        t_score = feature_dict.get( f"transition:START+{y_next}")
        new_score = feature_dict.get( f"transition:START+{y_next}+{x_instance[0]}", ninf)
        temp.append(t_score + new_score + scores[0, i])
    beta = aggreg_fn(np.array(temp))
    
    return scores, beta



def forward_backward(x_instance, x_instance_pos, y_vocab, feature_dict):
    n, d = len(x_instance), len(y_vocab)
    f_scores, alpha = forward(x_instance, x_instance_pos, y_vocab, feature_dict)
    b_scores, beta = backward(x_instance, x_instance_pos, y_vocab, feature_dict)
    
    feature_expected_count = defaultdict(float)
    
    for i in range(n):
        for y_i, y in enumerate(y_vocab):
            e_feature = f"emission:{y}+{x_instance[i]}"
            e_feature_pos = f"emission:{y}+{x_instance_pos[i]}"
            feature_expected_count[e_feature] += np.exp(f_scores[i, y_i] + b_scores[i, y_i] - alpha)
            feature_expected_count[e_feature_pos] += np.exp(f_scores[i, y_i] + b_scores[i, y_i] - alpha)
    
    for i, y_next in enumerate(y_vocab):
        t_feature = f"transition:START+{y_next}"
        feature_expected_count[t_feature] += np.exp(f_scores[0, i] + b_scores[0, i] - alpha)
        t_feature = f"transition:{y_next}+STOP"
        feature_expected_count[t_feature] += np.exp(f_scores[-1, i] + b_scores[-1, i] - alpha)
        
        t_feature = f"transition:START+{y_next}+x_instance[0]"
        feature_expected_count[t_feature] += np.exp(f_scores[0, i] + b_scores[0, i] - alpha)
        
    for y_i, y in enumerate(y_vocab):
        for y_next_i, y_next in enumerate(y_vocab):
            t_feature = f"transition:{y}+{y_next}"
            t_score = feature_dict.get(t_feature, ninf)
            total, new_total = 0, 0
            for i in range(n-1):
                e_score = feature_dict.get(f"emission:{y}+{x_instance[i]}", ninf)
                e_score_pos = feature_dict.get(f"emission:{y}+{x_instance_pos[i]}", ninf)
                new_feature = f"transition:{y}+{y_next}+{x_instance[i+1]}"
                new_score = feature_dict.get(new_feature, ninf)
                prob = np.exp(f_scores[i, y_i] + b_scores[i+1, y_next_i] + t_score + e_score + e_score_pos + new_score - alpha)
                feature_expected_count[t_feature] += prob 
                feature_expected_count[new_feature] += prob

    return feature_expected_count



def get_feature_count(x_instance, x_instance_pos, y_instance, feature_dict):
    feature_count = defaultdict(int)
    
    for x, y in zip(x_instance, y_instance): feature_count[f"emission:{y}+{x}"] += 1
    for x, y in zip(x_instance_pos, y_instance): feature_count[f"emission:{y}+{x}"] += 1
    
    for y_prev, y in zip(['START'] + y_instance, y_instance + ['STOP']):
        feature_count[f"transition:{y_prev}+{y}"] += 1

    for y_prev, y, x in zip(['START']+ y_instance[:-1], y_instance, x_instance):
        feature_count[f"transition:{y_prev}+{y}+{x}"] += 1
    
    return feature_count




def gradient_fn(x_data, x_data_pos, y_data, feature_dict, y_vocab, eta=0.1):
    feature_grad = defaultdict(float)
    
    for x_instance, x_instance_pos, y_instance in zip(x_data, x_data_pos, y_data):
        feature_expected_counts = forward_backward(x_instance, x_instance_pos, y_vocab, feature_dict)
        feature_actual_counts = get_feature_count(x_instance, x_instance_pos, y_instance, feature_dict)
        for k, v in feature_expected_counts.items(): feature_grad[k] += v
        for k, v in feature_actual_counts.items(): feature_grad[k] -= v    
    
    if eta > 0: 
        for k, v in feature_dict.items(): feature_grad[k] += 2*eta*v
    
    return feature_grad
        
    
def loss_fn(x_data, x_data_pos, y_data, feature_dict, y_vocab, eta=0):
    loss = 0
    for x_instance, x_instance_pos, y_instance in zip(x_data, x_data_pos, y_data):
        loss += loss_fn_instance(x_instance, x_instance_pos, y_instance, feature_dict, y_vocab) 
    reg_loss = eta * sum([o**2 for o in feature_dict.values()]) if eta > 0 else 0
    return loss + reg_loss



# Helper function
def numpy_to_dict(weight, feature_dict):
    for i,k in enumerate(feature_dict.keys()):
        feature_dict[k] = weight[i]
    return feature_dict

def dict_to_numpy(grads, feature_dict):
    np_grads = np.zeros(len(feature_dict))
    for i, k in enumerate(feature_dict.keys()):
        np_grads[i] = grads[k]
    return np_grads

def get_loss_grad(weight, *args):
    x_data, x_data_pos, y_data, feature_dict, y_vocab = args
    feature_dict = numpy_to_dict(weight, feature_dict)
    loss = loss_fn(x_data, x_data_pos, y_data, feature_dict, y_vocab, eta=0.1)
    print(loss)
    grads = gradient_fn(x_data, x_data_pos, y_data, feature_dict, y_vocab, eta=0.1)
    grads = dict_to_numpy(grads, feature_dict)
    return loss, grads

def callbackF(weight): print(f'Loss: \t {loss_fn(x_data, x_data_pos, y_data, feature_dict, y_vocab, eta=0.1):.4f}')

# %%
if __name__ == "__main__":
    full_dir = Path('full')
    save_dir = Path('save')
    ninf = -1e9
   
    x_data, x_data_pos, y_data = [read_data(full_dir/'train', i) for i in range(3)] 
    
    y_vocab = sorted(list(set([oo for o in y_data for oo in o])))
    x_vocab = list(set([oo for o in x_data for oo in o]))
    x_vocab_pos = sorted(list(set([oo for o in x_data_pos for oo in o])))
   
    e_dict = calc_e(x_data, y_data, x_vocab, y_vocab)
    e_dict_pos = calc_e(x_data_pos, y_data, x_vocab_pos, y_vocab)
    t_dict = calc_t(y_data, y_vocab)
    n_dict = calc_new(x_data, y_data, x_vocab, y_vocab)
    feature_dict = {**t_dict, **e_dict, **e_dict_pos, **n_dict}

# %%
# Gradient verification
import random
feature_key_checks = random.sample(feature_dict.keys(), 1000)
feature_gradients = gradient_fn(x_data, x_data_pos, y_data, feature_dict, y_vocab, eta=0)
loss1 = loss_fn(x_data, x_data_pos, y_data, feature_dict, y_vocab, eta=0)
delta = 1e-6

for feat_k in feature_key_checks:
    new_feature_dict = feature_dict.copy()
    new_feature_dict[feat_k] += delta
    loss2 = loss_fn(x_data, x_data_pos, y_data, new_feature_dict, y_vocab, eta=0)
    numerical_grad = (loss2 - loss1) / delta
    analytic_grad = feature_gradients[feat_k]
    if abs(numerical_grad - analytic_grad) / max(abs(numerical_grad), 1e-8) < 1e-5: 
        print(f'{feat_k:>40} passed gradient checking!')
    else:
        print(f'{feat_k:>40} didnot pass gradient checking!')

#     # Initialization
#     init_weight = np.zeros(len(feature_dict))
#     feature_dict = numpy_to_dict(init_weight, feature_dict)
    
    
#     # Training
#     print("Begin Training, this will take roughly 3 hours...")
#     result = fmin_l_bfgs_b( 
#         get_loss_grad, init_weight, pgtol=0.01, callback=callbackF,
#         args=(x_data, x_data_pos, y_data, feature_dict, y_vocab) 
#     )
    
#     # Save weights
#     feature_dict = numpy_to_dict(result[0], feature_dict)
#     weight_name = save_dir/'full-part5-2.json'
#     with open(weight_name, 'w') as f: json.dump(feature_dict, f)
#     print(f"Weight saved to {weight_name}")


#     # Inference
#     with open(weight_name) as f: feature_dict = json.load(f)
    
#     eval_filename = full_dir/'dev.p5.CRF.f4.out'
#     y_preds = inference(full_dir/'dev.in', y_vocab, feature_dict, eval_filename)
#     print(f"Wrote file to {eval_filename}")
   
#     # Evaluation
#     y_label = read_data(full_dir/'dev.out', column=2)
    
#     y_label = [oo for o in y_label for oo in o+['O']]
#     y_preds = [oo for o in y_preds for oo in o+['O']]
    
#     print('Evaluation on CRF with transition and word emission, and pos emission features')
#     prec, rec, f1 = evaluate(y_label, y_preds, verbose=False)
#     print(f'precision: {prec:.3f} \t rec: {rec:.3f} \t f1 {f1:.3f}')
# Out:
#           transition:B-nat+I-tim+whether passed gradient checking!
#        transition:I-gpe+I-eve+activities passed gradient checking!
#            transition:B-eve+I-per+pounds passed gradient checking!
#             transition:I-tim+I-geo+Uzbek passed gradient checking!
#        transition:I-eve+B-per+assertions passed gradient checking!
#          transition:B-art+B-geo+Israelis passed gradient checking!
#              transition:I-gpe+I-geo+59th passed gradient checking!
#            transition:I-tim+I-gpe+effect passed gradient checking!
#           transition:B-per+B-nat+smoking passed gradient checking!
#                transition:B-eve+I-eve+be passed gradient checking!
#           transition:B-eve+B-nat+rebuild passed gradient checking!
#        transition:I-geo+B-nat+commission passed gradient checking!
#               transition:O+I-eve+totaled passed gradient checking!
#         transition:I-eve+I-per+stabilize passed gradient checking!
#               transition:I-art+I-gpe+lit passed gradient checking!
#    transition:I-tim+B-art+industrialized passed gradient checking!
#            transition:B-nat+B-eve+Hassan passed gradient checking!
#           transition:B-nat+B-nat+Vincent passed gradient checking!
#              transition:I-per+B-nat+Nath passed gradient checking!
#    transition:B-org+B-geo+pro-government passed gradient checking!
#           transition:B-nat+I-art+further passed gradient checking!
#          transition:B-nat+B-nat+Northern passed gradient checking!
#        transition:B-nat+I-gpe+tenderness passed gradient checking!
#             transition:B-geo+B-art+Tokyo passed gradient checking!
#         transition:B-nat+B-art+estimated passed gradient checking!
#         transition:B-per+B-nat+incidents passed gradient checking!
#         transition:I-tim+I-gpe+automated passed gradient checking!
#               transition:O+B-tim+clerics passed gradient checking!
#              transition:I-art+I-per+ball passed gradient checking!
#                 transition:I-tim+O+DeLay passed gradient checking!
#              transition:I-art+I-eve+tree passed gradient checking!
#           transition:B-nat+I-geo+running passed gradient checking!
#           transition:B-eve+I-gpe+Orleans passed gradient checking!
#            transition:I-org+I-org+mother passed gradient checking!
#          transition:I-tim+B-geo+surprise passed gradient checking!
#                 emission:B-nat+Euphrates passed gradient checking!
#             transition:I-per+I-gpe+south passed gradient checking!
#                   emission:B-eve+serpent passed gradient checking!
#          transition:B-org+O+temperatures passed gradient checking!
#                      emission:B-org+club passed gradient checking!
#             transition:I-eve+B-eve+Salva passed gradient checking!
#        transition:START+B-nat+suspending passed gradient checking!
#                transition:O+B-eve+appeal passed gradient checking!
#            transition:I-gpe+I-per+advice passed gradient checking!
#         transition:I-tim+B-art+motivated passed gradient checking!
#          transition:B-org+B-tim+opinions passed gradient checking!
#         transition:I-tim+B-art+financial passed gradient checking!
#              transition:B-nat+I-per+Nice passed gradient checking!
#           transition:B-nat+I-art+Houston passed gradient checking!
#                   transition:I-eve+O+let passed gradient checking!
#                   emission:I-eve+freedom passed gradient checking!
#              transition:O+B-nat+Speaking passed gradient checking!
#             transition:I-art+I-eve+youth passed gradient checking!
#       transition:B-gpe+B-nat+provocation passed gradient checking!
#          transition:I-eve+I-gpe+violence passed gradient checking!
#            transition:I-art+B-eve+Public passed gradient checking!
#       transition:I-per+B-tim+restructure passed gradient checking!
#       transition:I-per+I-per+forecasters passed gradient checking!
#            transition:I-org+B-per+effect passed gradient checking!
#             transition:I-art+I-org+Texas passed gradient checking!
#      transition:I-art+I-tim+increasingly passed gradient checking!
#         transition:B-per+B-per+broadened passed gradient checking!
#              transition:O+I-org+tourists passed gradient checking!
#                     emission:I-geo+study passed gradient checking!
#               transition:B-per+B-eve+put passed gradient checking!
#               transition:B-geo+I-geo+ate passed gradient checking!
#            transition:B-art+B-gpe+locked passed gradient checking!
#         transition:B-geo+B-tim+Milosevic passed gradient checking!
#          transition:I-geo+B-geo+hospital passed gradient checking!
#              transition:B-org+B-org+food passed gradient checking!
#                       emission:I-geo+won passed gradient checking!
#           transition:B-art+B-art+Nicolas passed gradient checking!
#           transition:START+I-tim+release passed gradient checking!
#           transition:B-per+B-org+uniform passed gradient checking!
#          transition:B-eve+I-org+hectares passed gradient checking!
#      transition:O+I-per+characterization passed gradient checking!
#           transition:I-gpe+I-art+reports passed gradient checking!
#             transition:B-tim+I-art+boost passed gradient checking!
#               transition:I-geo+O+violent passed gradient checking!
#           transition:B-eve+B-gpe+soaring passed gradient checking!
#            transition:B-art+B-gpe+newest passed gradient checking!
#               transition:B-gpe+I-gpe+cup passed gradient checking!
#       transition:I-geo+B-tim+Development passed gradient checking!
#                   transition:O+I-eve+end passed gradient checking!
#              transition:B-per+I-art+rare passed gradient checking!
#      transition:I-tim+B-eve+increasingly passed gradient checking!
#                transition:B-nat+I-gpe+16 passed gradient checking!
#          transition:B-art+B-gpe+includes passed gradient checking!
#          transition:I-org+B-org+although passed gradient checking!
#            transition:B-org+B-geo+troops passed gradient checking!
#           transition:B-nat+I-gpe+exhibit passed gradient checking!
#             transition:B-eve+B-per+judge passed gradient checking!
#           transition:START+B-eve+friends passed gradient checking!
#        transition:I-gpe+B-org+homosexual passed gradient checking!
#           transition:B-art+I-per+Bolivia passed gradient checking!
#         transition:B-tim+I-per+opponents passed gradient checking!
#           transition:B-geo+I-geo+burning passed gradient checking!
#       transition:B-org+I-art+anti-doping passed gradient checking!
#        transition:B-nat+B-tim+Gremelmayr passed gradient checking!
#              transition:START+I-art+sack passed gradient checking!
#            transition:B-nat+I-eve+pounds passed gradient checking!
#             transition:I-eve+O+Farabaugh passed gradient checking!
#                    emission:B-nat+10,000 passed gradient checking!
#        transition:B-tim+B-nat+principles passed gradient checking!
#           transition:I-geo+I-eve+Lebanon passed gradient checking!
#           transition:I-gpe+B-eve+Indiana passed gradient checking!
#              transition:I-gpe+I-org+1891 passed gradient checking!
#          transition:B-art+B-eve+eligible passed gradient checking!
#           transition:B-geo+I-gpe+exhibit passed gradient checking!
#             transition:B-per+B-art+23.25 passed gradient checking!
#               transition:O+B-org+erupted passed gradient checking!
#            transition:I-geo+B-per+series passed gradient checking!
#             transition:B-art+B-art+Bahia passed gradient checking!
#            transition:B-tim+I-org+owners passed gradient checking!
#             transition:B-org+B-tim+drawn passed gradient checking!
#             transition:B-eve+I-per+judge passed gradient checking!
#                 transition:I-art+B-gpe+$ passed gradient checking!
#            transition:B-gpe+I-per+rights passed gradient checking!
#              transition:I-eve+B-org+more passed gradient checking!
#        transition:B-gpe+I-org+long-range passed gradient checking!
#             transition:O+I-org+Farabaugh passed gradient checking!
#            transition:B-tim+B-art+Barack passed gradient checking!
#            transition:I-gpe+I-tim+member passed gradient checking!
#            transition:I-gpe+B-art+banned passed gradient checking!
#         transition:B-per+B-per+stabilize passed gradient checking!
#        transition:I-geo+I-geo+Abdolsamad passed gradient checking!
#              transition:I-eve+B-nat+Mike passed gradient checking!
#             transition:I-per+B-per+Voice passed gradient checking!
#                     emission:I-tim+spill passed gradient checking!
#           transition:I-gpe+I-gpe+Chinese passed gradient checking!
#               transition:B-tim+I-tim+run passed gradient checking!
#            transition:B-geo+B-tim+fourth passed gradient checking!
#              transition:I-per+I-geo+Gen. passed gradient checking!
#           transition:B-per+B-art+details passed gradient checking!
#              transition:B-eve+B-nat+face passed gradient checking!
#       transition:I-geo+B-tim+Agriculture passed gradient checking!
#           transition:I-geo+B-gpe+figures passed gradient checking!
#               transition:O+B-nat+Kennedy passed gradient checking!
#         transition:B-tim+I-gpe+Zapatista passed gradient checking!
#              transition:B-nat+B-per+wide passed gradient checking!
#           transition:I-art+I-per+refugee passed gradient checking!
#        transition:B-org+B-art+operations passed gradient checking!
#           transition:I-geo+B-eve+soaring passed gradient checking!
#                 transition:O+B-nat+Birds passed gradient checking!
#            transition:START+B-geo+battle passed gradient checking!
#              transition:B-per+I-tim+Hang passed gradient checking!
#        transition:B-eve+B-eve+legislator passed gradient checking!
#      transition:I-tim+I-gpe+eight-tenths passed gradient checking!
#            transition:B-tim+I-tim+staged passed gradient checking!
#               transition:I-per+O+Reuters passed gradient checking!
#           transition:START+B-art+protest passed gradient checking!
#             transition:I-geo+I-geo+opium passed gradient checking!
#          transition:I-geo+I-art+Cemetery passed gradient checking!
#           transition:START+I-gpe+Russian passed gradient checking!
#                transition:B-gpe+B-geo+As passed gradient checking!
#            transition:B-gpe+B-art+Sharon passed gradient checking!
#        transition:I-art+I-art+privileges passed gradient checking!
#        transition:I-eve+I-geo+annexation passed gradient checking!
#           transition:B-eve+I-tim+Michael passed gradient checking!
#         transition:B-art+B-per+extremist passed gradient checking!
#         transition:B-org+B-tim+mid-1990s passed gradient checking!
#                     transition:O+O+tests passed gradient checking!
#        transition:O+B-geo+Port-au-Prince passed gradient checking!
#            transition:I-art+I-per+senior passed gradient checking!
#         transition:I-tim+I-gpe+territory passed gradient checking!
#              transition:I-eve+I-geo+Rath passed gradient checking!
#            transition:START+I-art+summit passed gradient checking!
# transition:B-org+B-nat+insurgency-plagued passed gradient checking!
#           transition:I-geo+B-nat+outside passed gradient checking!
#        transition:I-gpe+B-eve+suspending passed gradient checking!
#           transition:B-nat+B-per+control passed gradient checking!
#           transition:B-art+I-eve+Justice passed gradient checking!
#         transition:B-tim+B-geo+Iran-Iraq passed gradient checking!
#        transition:I-per+I-eve+occupation passed gradient checking!
#           transition:I-eve+B-gpe+Crimean passed gradient checking!
#           transition:I-tim+B-nat+militia passed gradient checking!
#                   emission:B-tim+Tuesday didnot pass gradient checking!
#           transition:START+B-gpe+friends passed gradient checking!
#               transition:B-tim+I-eve+250 passed gradient checking!
#                   emission:I-gpe+al-Aqsa passed gradient checking!
#                transition:O+I-tim+toward passed gradient checking!
#             transition:B-org+B-art+relay passed gradient checking!
#            transition:I-tim+B-org+youths passed gradient checking!
#           transition:B-tim+I-org+Abizaid passed gradient checking!
#         transition:B-tim+B-eve+turbulent passed gradient checking!
#      transition:START+O+election-related passed gradient checking!
#                 transition:B-per+O+joint passed gradient checking!
#           transition:B-geo+I-art+holiday passed gradient checking!
#             transition:START+I-art+early passed gradient checking!
#        transition:B-art+I-per+undergoing passed gradient checking!
#          transition:B-org+B-per+troubled passed gradient checking!
#         transition:I-art+B-geo+candidate passed gradient checking!
#          transition:B-tim+I-art+articles passed gradient checking!
#         transition:B-per+B-geo+determine passed gradient checking!
#            transition:B-gpe+B-org+coping passed gradient checking!
#              transition:B-geo+I-eve+Loeb passed gradient checking!
#              transition:B-tim+B-nat+post passed gradient checking!
#          transition:B-geo+B-eve+families passed gradient checking!
#        transition:B-eve+I-geo+diplomatic passed gradient checking!
#              transition:I-per+I-art+take passed gradient checking!
#             transition:B-eve+I-art+Obama passed gradient checking!
#       transition:I-tim+I-eve+22-year-old passed gradient checking!
#             transition:B-gpe+I-gpe+adopt passed gradient checking!
#         transition:I-geo+I-gpe+alongside passed gradient checking!
#        transition:START+I-art+provincial passed gradient checking!
#          transition:B-nat+I-tim+Frontier passed gradient checking!
#        transition:I-gpe+B-gpe+Gremelmayr passed gradient checking!
#               transition:B-eve+I-per+can passed gradient checking!
#           transition:I-org+I-tim+someone passed gradient checking!
#          transition:B-gpe+I-tim+enclosed passed gradient checking!
#                      transition:O+O+fist passed gradient checking!
#             transition:B-gpe+B-org+brawl passed gradient checking!
#        transition:B-per+I-per+additional passed gradient checking!
#                transition:I-gpe+O+Jordan passed gradient checking!
#          transition:B-art+B-art+students passed gradient checking!
#            transition:I-tim+I-per+bombed passed gradient checking!
#             transition:I-tim+I-gpe+Sisco passed gradient checking!
#              transition:O+B-eve+declined passed gradient checking!
#            transition:B-tim+I-eve+Former passed gradient checking!
#         transition:B-tim+B-eve+persisted passed gradient checking!
#       transition:B-org+B-geo+criticizing passed gradient checking!
#           transition:I-geo+B-org+Jacques passed gradient checking!
#             transition:I-gpe+B-per+small passed gradient checking!
#              transition:START+B-gpe+July passed gradient checking!
#                    emission:B-eve+bombed passed gradient checking!
#            transition:I-per+B-geo+throne passed gradient checking!
#                transition:I-per+I-eve+46 passed gradient checking!
#              transition:B-per+I-tim+Want passed gradient checking!
#             transition:B-geo+I-gpe+range passed gradient checking!
#                transition:I-gpe+O+annual passed gradient checking!
#             transition:I-art+B-eve+urged passed gradient checking!
#             transition:I-tim+I-tim+8,200 passed gradient checking!
#           transition:B-eve+B-per+abusing passed gradient checking!
#                   emission:B-nat+designs passed gradient checking!
#            transition:I-gpe+I-tim+Turkey passed gradient checking!
#         transition:B-eve+I-per+Witnesses passed gradient checking!
#             transition:I-tim+B-per+carry passed gradient checking!
#            transition:B-tim+B-tim+40-car passed gradient checking!
#             transition:B-nat+I-tim+union passed gradient checking!
#          transition:I-tim+I-art+warrants passed gradient checking!
#           transition:I-geo+B-tim+Project passed gradient checking!
#             transition:B-tim+B-art+calls passed gradient checking!
#           transition:I-eve+B-eve+Compact passed gradient checking!
#           transition:I-eve+B-nat+willing passed gradient checking!
#         transition:B-gpe+O+international passed gradient checking!
#                     emission:B-eve+space passed gradient checking!
#           transition:START+B-org+Cricket passed gradient checking!
#         transition:I-geo+B-art+authority passed gradient checking!
#         transition:I-geo+B-tim+Zapatista passed gradient checking!
#         transition:START+B-eve+directors passed gradient checking!
#            transition:B-nat+B-geo+unless passed gradient checking!
#      transition:B-eve+B-nat+Seyranlioglu passed gradient checking!
#              transition:B-nat+B-geo+flew passed gradient checking!
#           transition:B-gpe+B-org+foreign passed gradient checking!
#            transition:I-org+I-art+Sweden passed gradient checking!
#          transition:I-org+B-art+inferior passed gradient checking!
#            transition:B-org+I-art+survey passed gradient checking!
#         transition:B-gpe+I-geo+survivors passed gradient checking!
#            transition:B-gpe+B-nat+return passed gradient checking!
#           transition:START+I-geo+rallied passed gradient checking!
#          transition:B-tim+B-art+reminded passed gradient checking!
#        transition:B-tim+B-org+Hemisphere passed gradient checking!
#             transition:B-art+B-eve+years passed gradient checking!
#         transition:B-art+I-tim+automated passed gradient checking!
#          transition:I-eve+B-art+consists passed gradient checking!
#           transition:START+B-nat+donated passed gradient checking!
#                     emission:B-eve+found passed gradient checking!
#           transition:B-gpe+B-tim+Orleans passed gradient checking!
#       transition:B-nat+B-org+century-old passed gradient checking!
#          transition:I-art+B-eve+Manmohan passed gradient checking!
#        transition:B-tim+B-gpe+inequality passed gradient checking!
#             transition:O+I-tim+el-Bashir passed gradient checking!
#            transition:I-gpe+I-gpe+eagles passed gradient checking!
#         transition:I-art+I-geo+introduce passed gradient checking!
#                    emission:B-art+Beatle passed gradient checking!
#         transition:I-tim+B-tim+Hurricane passed gradient checking!
#            transition:B-geo+B-gpe+France passed gradient checking!
#              transition:O+I-eve+survived passed gradient checking!
#       transition:I-tim+I-tim+researchers passed gradient checking!
# transition:I-per+B-eve+Bosnia-Herzegovina passed gradient checking!
#         transition:I-per+I-gpe+Ching-hsi passed gradient checking!
#       transition:I-per+B-per+helicopters passed gradient checking!
#           transition:I-per+I-tim+Koizumi passed gradient checking!
#                transition:B-gpe+I-org+me passed gradient checking!
#                 transition:I-org+B-gpe+! passed gradient checking!
#            transition:B-per+I-eve+Indian passed gradient checking!
#        transition:I-tim+I-per+Ambassador passed gradient checking!
#            transition:I-gpe+I-gpe+marked passed gradient checking!
#             transition:B-eve+B-gpe+crime passed gradient checking!
#           transition:B-gpe+B-nat+ordered passed gradient checking!
#          transition:B-gpe+B-per+original passed gradient checking!
#                  transition:O+B-gpe+U.S. passed gradient checking!
#              transition:I-art+I-art+part passed gradient checking!
#            transition:B-geo+B-eve+months passed gradient checking!
#         transition:I-art+B-nat+committee passed gradient checking!
#            transition:I-geo+B-nat+Niccum passed gradient checking!
#            transition:I-per+I-gpe+little passed gradient checking!
#           transition:I-per+B-eve+failure passed gradient checking!
#            transition:B-geo+I-art+retire passed gradient checking!
#            transition:START+B-eve+global passed gradient checking!
#          transition:B-org+B-tim+deadline passed gradient checking!
#           transition:I-org+B-geo+sitting passed gradient checking!
#          transition:I-org+B-nat+practice passed gradient checking!
#           transition:I-art+I-art+Lashkar passed gradient checking!
#         transition:I-per+I-org+blackouts passed gradient checking!
#                    emission:I-per+Bogota passed gradient checking!
#           transition:B-org+B-eve+Between passed gradient checking!
#           transition:START+B-org+cyclist passed gradient checking!
#          transition:B-per+B-geo+smuggled passed gradient checking!
#           transition:I-art+B-geo+expires passed gradient checking!
#                 transition:I-art+B-nat+% passed gradient checking!
#          transition:I-geo+B-art+consists passed gradient checking!
#           transition:B-geo+I-per+islands passed gradient checking!
#               transition:START+I-per+DRC passed gradient checking!
#              transition:I-gpe+I-org+tell passed gradient checking!
#             transition:B-nat+B-eve+Ganji passed gradient checking!
#              transition:I-org+I-org+ties passed gradient checking!
#           transition:B-tim+B-tim+staging passed gradient checking!
#            transition:I-org+I-org+tested passed gradient checking!
#             transition:B-geo+I-geo+Style passed gradient checking!
#                   emission:B-tim+Bwakira passed gradient checking!
#    transition:I-art+B-eve+U.N.-Congolese passed gradient checking!
#            transition:B-art+I-org+Ground passed gradient checking!
#              transition:I-per+I-org+many passed gradient checking!
#           transition:I-art+B-eve+decided passed gradient checking!
#           transition:I-org+B-nat+animals passed gradient checking!
#          transition:I-art+B-nat+undersea passed gradient checking!
#     transition:B-geo+I-eve+Investigators passed gradient checking!
#             transition:B-per+B-geo+fired passed gradient checking!
#                transition:B-gpe+B-eve+so passed gradient checking!
#                    transition:I-per+O+12 passed gradient checking!
#         transition:B-tim+B-per+unskilled passed gradient checking!
#              transition:I-geo+I-per+Kiir passed gradient checking!
#         transition:B-nat+B-geo+Following passed gradient checking!
#                 transition:B-nat+O+goods passed gradient checking!
#                 transition:START+B-nat+4 passed gradient checking!
#              transition:O+I-eve+relating passed gradient checking!
#         transition:I-org+I-tim+phosphate passed gradient checking!
#             transition:B-eve+B-art+Press passed gradient checking!
#       transition:B-per+I-per+projectiles passed gradient checking!
#             transition:B-tim+I-geo+drive passed gradient checking!
#             transition:B-per+B-nat+razor passed gradient checking!
#              transition:I-gpe+B-eve+most passed gradient checking!
#         transition:B-tim+B-per+residents passed gradient checking!
#         transition:B-org+I-per+spreading passed gradient checking!
#           transition:B-geo+B-tim+Houston passed gradient checking!
#              transition:B-eve+I-per+1923 passed gradient checking!
#           transition:I-per+I-per+Spanish passed gradient checking!
#             transition:B-tim+I-eve+paper passed gradient checking!
#             transition:I-eve+I-org+Tenet passed gradient checking!
#               transition:O+B-gpe+trapped passed gradient checking!
#                    emission:I-eve+Rudolf passed gradient checking!
#             transition:I-tim+B-nat+crash passed gradient checking!
#               transition:O+I-eve+Phoenix passed gradient checking!
#           transition:I-tim+I-geo+refugee passed gradient checking!
#            transition:B-art+B-org+resign passed gradient checking!
#              transition:B-nat+B-per+dead passed gradient checking!
#            transition:B-tim+B-org+crimes passed gradient checking!
#          transition:I-gpe+I-art+original passed gradient checking!
#           transition:B-gpe+I-org+hanging passed gradient checking!
#      transition:O+B-eve+intercontinental passed gradient checking!
#            transition:I-art+B-art+troops passed gradient checking!
#           transition:I-art+B-org+Koizumi passed gradient checking!
#                   emission:B-org+comment passed gradient checking!
#       transition:B-per+I-per+parliaments passed gradient checking!
#              transition:I-geo+B-art+name passed gradient checking!
#                transition:O+I-tim+Monday passed gradient checking!
#            transition:I-art+B-art+Kosovo passed gradient checking!
#          transition:B-gpe+I-art+Internet passed gradient checking!
# transition:I-tim+B-org+Bosnia-Herzegovina passed gradient checking!
#                 transition:I-gpe+O+begin passed gradient checking!
#     transition:I-gpe+B-gpe+International passed gradient checking!
#           transition:START+I-per+Erdogan passed gradient checking!
#       transition:B-eve+B-nat+biographies passed gradient checking!
#              transition:I-per+I-art+lead passed gradient checking!
#        transition:I-geo+I-geo+astronauts passed gradient checking!
#                transition:B-eve+B-per+in passed gradient checking!
#        transition:B-eve+B-gpe+solidarity passed gradient checking!
#            transition:B-art+B-eve+guilty passed gradient checking!
#               transition:O+I-tim+factors passed gradient checking!
#             transition:I-tim+B-per+night passed gradient checking!
#             transition:B-art+I-geo+phase passed gradient checking!
#            transition:I-gpe+O+submission passed gradient checking!
#        transition:I-per+B-geo+Indonesian passed gradient checking!
#      transition:B-per+B-tim+disagreement passed gradient checking!
#          transition:B-tim+B-nat+withdraw passed gradient checking!
#            transition:B-per+I-gpe+market passed gradient checking!
#           transition:B-nat+I-org+lawyers passed gradient checking!
#         transition:B-gpe+I-gpe+sidelines passed gradient checking!
#       transition:I-geo+B-nat+recognizing passed gradient checking!
#              transition:B-gpe+B-gpe+Lama passed gradient checking!
#                transition:I-eve+B-eve+10 passed gradient checking!
#                   emission:B-per+helping passed gradient checking!
#             transition:I-tim+I-gpe+block passed gradient checking!
#         transition:B-art+I-geo+personnel passed gradient checking!
#       transition:START+I-eve+recommended passed gradient checking!
#               transition:B-per+B-org+Air passed gradient checking!
#     transition:B-art+B-org+prescriptions passed gradient checking!
#        transition:B-nat+B-org+prosperous passed gradient checking!
#                    emission:I-gpe+fellow passed gradient checking!
#       transition:B-geo+I-per+provisional passed gradient checking!
#             transition:START+B-gpe+adopt passed gradient checking!
#              transition:B-eve+B-art+NASA passed gradient checking!
#              transition:B-org+O+Israelis passed gradient checking!
#        transition:B-per+I-gpe+protesters passed gradient checking!
#             transition:I-gpe+B-geo+Kabul passed gradient checking!
#           transition:I-art+B-eve+militia passed gradient checking!
#            transition:B-gpe+I-eve+asking passed gradient checking!
#         transition:B-eve+I-eve+mid-1990s passed gradient checking!
#           transition:I-art+O+third-place passed gradient checking!
#          transition:I-gpe+B-tim+Kye-gwan passed gradient checking!
#           transition:START+B-org+trading passed gradient checking!
#        transition:B-gpe+I-art+defendants passed gradient checking!
#          transition:B-eve+I-org+appeared passed gradient checking!
#            transition:I-geo+I-tim+errors passed gradient checking!
#       transition:B-tim+B-nat+surrendered passed gradient checking!
#        transition:B-gpe+I-per+confirming passed gradient checking!
#           transition:B-per+B-art+Cypriot passed gradient checking!
#              transition:B-nat+B-org+Peru passed gradient checking!
#             transition:B-org+B-org+draft passed gradient checking!
#                          emission:O+Catu passed gradient checking!
#          transition:START+I-tim+Yongbyon passed gradient checking!
#         transition:B-org+I-geo+primaries passed gradient checking!
#            transition:B-eve+I-per+called passed gradient checking!
#            transition:START+I-org+agreed passed gradient checking!
#              transition:I-art+B-tim+yard passed gradient checking!
#            transition:B-tim+O+concession passed gradient checking!
#           transition:B-per+B-per+cleaned passed gradient checking!
#          transition:B-gpe+B-gpe+facility passed gradient checking!
#       transition:B-art+I-tim+instruments passed gradient checking!
#         transition:B-per+I-org+attackers passed gradient checking!
#              transition:I-org+B-art+snow passed gradient checking!
#          transition:START+I-geo+prisoner passed gradient checking!
#            transition:I-per+I-tim+struck passed gradient checking!
#      transition:B-art+B-org+independence passed gradient checking!
#                  transition:O+I-per+else passed gradient checking!
#       transition:I-org+B-geo+intensified passed gradient checking!
#           transition:B-org+O+Palestinian passed gradient checking!
#          transition:I-tim+I-geo+domestic passed gradient checking!
#           transition:B-geo+B-eve+Afghans passed gradient checking!
#              transition:B-nat+O+councils passed gradient checking!
#          transition:I-art+B-geo+bleeding passed gradient checking!
#            transition:B-per+O+accountant passed gradient checking!
#           transition:B-geo+B-nat+regions passed gradient checking!
#             transition:O+B-eve+stabilize passed gradient checking!
#             transition:I-art+I-org+happy passed gradient checking!
#              transition:O+B-per+endorsed passed gradient checking!
#           transition:START+B-tim+ordered passed gradient checking!
#            transition:B-org+I-per+appeal passed gradient checking!
#           transition:B-geo+I-tim+Vitoria passed gradient checking!
#          transition:B-gpe+I-gpe+Assembly passed gradient checking!
#          transition:I-eve+I-org+weaponry passed gradient checking!
#           transition:B-tim+B-nat+actions passed gradient checking!
#              transition:I-geo+I-eve+risk passed gradient checking!
#         transition:I-eve+B-gpe+Buildings passed gradient checking!
#          transition:I-gpe+B-geo+Province passed gradient checking!
#                    emission:I-tim+Maazou passed gradient checking!
#          transition:B-eve+B-gpe+business passed gradient checking!
#           transition:B-nat+I-gpe+renewed passed gradient checking!
#           transition:I-art+I-gpe+Mahmoud passed gradient checking!
#       transition:B-gpe+B-org+Afghanistan passed gradient checking!
#            transition:B-org+B-eve+Chavez passed gradient checking!
#                 transition:B-org+O+opium passed gradient checking!
#             transition:I-eve+B-gpe+young passed gradient checking!
#          transition:B-geo+B-per+enclosed passed gradient checking!
#           transition:START+B-per+players passed gradient checking!
#         transition:I-art+I-tim+Americans passed gradient checking!
#              transition:B-art+I-per+else passed gradient checking!
#             transition:B-per+B-eve+types passed gradient checking!
#             transition:B-art+B-org+Joint passed gradient checking!
#         transition:I-geo+I-tim+broadened passed gradient checking!
#          transition:B-nat+I-eve+stand-up passed gradient checking!
#         transition:I-gpe+B-geo+determine passed gradient checking!
#          transition:START+B-geo+declared passed gradient checking!
#                      emission:I-art+drop passed gradient checking!
#     transition:I-gpe+I-art+significantly passed gradient checking!
#        transition:I-eve+I-per+annexation passed gradient checking!
#         transition:B-geo+I-org+belonging passed gradient checking!
#          transition:B-gpe+I-eve+vehicles passed gradient checking!
#                     emission:I-tim+Rally passed gradient checking!
#                 emission:B-gpe+overthrow passed gradient checking!
#          transition:I-geo+I-geo+al-Qaida passed gradient checking!
#              transition:I-gpe+B-gpe+iron passed gradient checking!
#                transition:B-eve+I-gpe+81 passed gradient checking!
#                    emission:B-eve+Tassos passed gradient checking!
#          transition:I-org+B-art+Khartoum passed gradient checking!
#             transition:B-tim+B-nat+draft passed gradient checking!
#                transition:I-org+O+decade passed gradient checking!
#              transition:B-per+B-org+boys passed gradient checking!
#         transition:I-geo+B-geo+treatment passed gradient checking!
#         transition:B-org+I-art+Kathmandu passed gradient checking!
#         transition:B-tim+I-gpe+conflicts passed gradient checking!
#              transition:I-per+B-gpe+1.06 passed gradient checking!
#        transition:B-nat+I-art+hereditary passed gradient checking!
#        transition:B-tim+B-tim+Television passed gradient checking!
#              transition:B-per+I-tim+Iran passed gradient checking!
#          transition:I-gpe+B-per+property passed gradient checking!
#            transition:I-geo+B-art+around passed gradient checking!
#            transition:B-geo+B-per+costly passed gradient checking!
#           transition:O+I-art+sovereignty passed gradient checking!
#                  emission:B-org+7,00,000 passed gradient checking!
#          transition:I-gpe+I-geo+obstruct passed gradient checking!
#             transition:I-gpe+I-gpe+early passed gradient checking!
#           transition:B-gpe+I-geo+Kurdish passed gradient checking!
#           transition:I-geo+B-nat+Caracas passed gradient checking!
#            transition:I-per+I-geo+Before passed gradient checking!
#           transition:I-org+B-art+poorest passed gradient checking!
#         transition:I-org+B-org+attorneys passed gradient checking!
#         transition:B-nat+B-per+Farabaugh passed gradient checking!
#            transition:B-nat+I-gpe+remove passed gradient checking!
#      transition:I-eve+B-nat+applications passed gradient checking!
#              transition:B-eve+I-geo+Khin passed gradient checking!
#            transition:I-eve+O+Associated passed gradient checking!
#               transition:B-per+I-per+May passed gradient checking!
#              transition:I-art+B-per+swap passed gradient checking!
#       transition:B-tim+B-nat+predictions passed gradient checking!
#         transition:B-eve+I-eve+belonging passed gradient checking!
#           transition:I-org+B-per+maximum passed gradient checking!
#         transition:B-gpe+B-eve+inspector passed gradient checking!
#             transition:I-tim+B-nat+house passed gradient checking!
#           transition:B-geo+B-geo+justice passed gradient checking!
#       transition:I-tim+I-eve+parliaments passed gradient checking!
#              transition:I-eve+I-org+tour passed gradient checking!
#          transition:B-nat+B-org+retrieve passed gradient checking!
#       transition:START+B-eve+Politicians passed gradient checking!
#           transition:B-per+B-gpe+History passed gradient checking!
#           transition:B-eve+I-eve+Indiana passed gradient checking!
#             transition:B-org+I-gpe+river passed gradient checking!
#               transition:START+B-org+bog passed gradient checking!
#         transition:I-gpe+I-eve+equipment passed gradient checking!
#        transition:B-eve+B-tim+Associated passed gradient checking!
#             transition:B-per+I-art+check passed gradient checking!
#            transition:START+I-eve+defend passed gradient checking!
#             transition:B-geo+I-per+water passed gradient checking!
#              transition:B-eve+B-eve+Post passed gradient checking!
#         transition:B-per+I-geo+determine passed gradient checking!
#            transition:I-geo+I-org+profit passed gradient checking!
#           transition:I-art+B-art+species passed gradient checking!
#                 transition:O+B-tim+Three passed gradient checking!
#                 transition:I-org+O+freed passed gradient checking!
#             transition:B-geo+B-tim+faced passed gradient checking!
#            emission:I-tim+implementation passed gradient checking!
#            transition:B-per+B-org+supply passed gradient checking!
#             emission:B-eve+court-martial passed gradient checking!
#           transition:I-art+I-gpe+centers passed gradient checking!
#           transition:B-org+I-eve+sitting passed gradient checking!
#             transition:I-tim+B-geo+would passed gradient checking!
#        transition:B-tim+I-tim+Venezuelan passed gradient checking!
#          transition:B-art+B-eve+attorney passed gradient checking!
#       transition:B-gpe+I-tim+biographies passed gradient checking!
#          transition:I-geo+B-eve+gridlock passed gradient checking!
#            transition:I-art+B-eve+London passed gradient checking!
#             transition:I-eve+B-nat+visit passed gradient checking!
#              transition:B-geo+I-art+gold passed gradient checking!
#             transition:I-org+B-org+drive passed gradient checking!
#         transition:I-geo+I-geo+territory passed gradient checking!
#               transition:O+B-nat+removed passed gradient checking!
#              transition:I-art+I-eve+Hill passed gradient checking!
#              transition:O+B-eve+District passed gradient checking!
#          transition:I-tim+I-tim+2,30,000 passed gradient checking!
#             transition:B-per+O+Pyongyang passed gradient checking!
#               transition:B-tim+B-geo+lay passed gradient checking!
#           transition:I-gpe+B-org+bowlers passed gradient checking!
#         transition:B-gpe+B-gpe+week-long passed gradient checking!
#          transition:I-art+I-eve+McDonald passed gradient checking!
#                transition:B-tim+B-nat+BP passed gradient checking!
#              transition:I-tim+B-per+they passed gradient checking!
#           transition:B-art+I-geo+certain passed gradient checking!
#                  emission:I-eve+branches passed gradient checking!
#                 transition:B-per+I-org+! passed gradient checking!
#       transition:B-geo+B-geo+predictions passed gradient checking!
#           transition:B-gpe+B-org+stalled passed gradient checking!
#           transition:B-eve+B-tim+started passed gradient checking!
#            transition:I-eve+B-art+member passed gradient checking!
#                     emission:O+detention passed gradient checking!
#               transition:O+I-org+project passed gradient checking!
#          transition:I-art+B-geo+tribunal passed gradient checking!
#          transition:B-org+B-org+problems passed gradient checking!
#       transition:I-eve+I-per+replacement passed gradient checking!
#            transition:B-geo+O+investment passed gradient checking!
#            transition:B-gpe+B-per+person passed gradient checking!
#           transition:I-gpe+I-art+warrant passed gradient checking!
#                 emission:B-tim+immigrant passed gradient checking!
#           transition:I-per+I-eve+Tibetan passed gradient checking!
#         transition:I-geo+B-org+militants passed gradient checking!
#              transition:I-gpe+I-per+Mike passed gradient checking!
#              transition:B-nat+B-art+Jean passed gradient checking!
#       transition:B-art+B-geo+Association passed gradient checking!
#         transition:B-per+B-nat+searchers passed gradient checking!
#          transition:B-gpe+B-nat+admitted passed gradient checking!
#                   transition:O+B-per+5.1 passed gradient checking!
#           transition:I-geo+B-tim+African passed gradient checking!
#                 emission:I-per+Suspected passed gradient checking!
#           transition:I-org+B-art+nuclear passed gradient checking!
#         transition:B-geo+I-gpe+expanding passed gradient checking!
#                   emission:B-geo+casings passed gradient checking!
#         transition:B-org+I-per+Iran-Iraq passed gradient checking!
#           transition:I-org+B-org+waivers passed gradient checking!
#            transition:B-geo+I-art+recall passed gradient checking!
#        transition:START+B-tim+networking passed gradient checking!
#           transition:B-art+I-eve+pockets passed gradient checking!
#              transition:I-eve+I-eve+SPLM passed gradient checking!
#                  transition:B-org+O+ward passed gradient checking!
#           transition:B-art+I-gpe+advisor passed gradient checking!
#           transition:O+B-org+settlements passed gradient checking!
#         transition:I-gpe+B-tim+week-long passed gradient checking!
#            transition:I-geo+B-geo+minute passed gradient checking!
#            transition:I-art+B-org+failed passed gradient checking!
#                  transition:START+O+teen passed gradient checking!
#          transition:I-geo+B-art+Alliance passed gradient checking!
#               transition:I-gpe+B-nat+275 passed gradient checking!
#           transition:I-gpe+I-org+decades passed gradient checking!
#              transition:I-gpe+I-eve+than passed gradient checking!
#              transition:I-geo+B-art+1997 passed gradient checking!
#      transition:I-gpe+I-art+high-profile passed gradient checking!
#                  emission:I-art+promised passed gradient checking!
#            transition:I-geo+I-org+moving passed gradient checking!
#           transition:B-tim+B-org+country passed gradient checking!
#                transition:B-gpe+O+appeal passed gradient checking!
#         transition:B-eve+B-org+destroyed passed gradient checking!
#              transition:B-gpe+I-tim+left passed gradient checking!
#            transition:B-tim+I-tim+action passed gradient checking!
#               transition:START+B-per+use passed gradient checking!
#              transition:B-gpe+I-eve+jobs passed gradient checking!
#          transition:START+I-art+stronger passed gradient checking!
#            transition:I-gpe+I-eve+Sharon passed gradient checking!
#            transition:B-geo+I-geo+helped passed gradient checking!
#         transition:I-gpe+I-org+venturing passed gradient checking!
#           transition:B-tim+B-nat+Foreman passed gradient checking!
#         transition:B-art+I-per+Brazilian passed gradient checking!
#    transition:I-tim+I-eve+self-inflicted passed gradient checking!
#              transition:B-art+B-geo+Gen. passed gradient checking!
#               transition:O+B-art+clerics passed gradient checking!
#              transition:I-geo+B-geo+what passed gradient checking!
#               transition:B-tim+B-geo+now passed gradient checking!
#             transition:B-geo+B-geo+opium passed gradient checking!
#           transition:I-geo+I-art+invaded passed gradient checking!
#         transition:B-nat+B-per+thousands passed gradient checking!
#                  transition:O+I-gpe+both passed gradient checking!
#         transition:I-tim+I-art+neighbors passed gradient checking!
#            transition:B-art+I-geo+wished passed gradient checking!
#           transition:B-gpe+I-eve+violent passed gradient checking!
#           transition:B-eve+I-eve+another passed gradient checking!
#              transition:B-eve+I-gpe+1989 passed gradient checking!
#           transition:B-gpe+B-eve+ushered passed gradient checking!
#             transition:B-geo+B-eve+Chang passed gradient checking!
#                 transition:O+B-nat+Saudi passed gradient checking!
#            transition:I-gpe+B-tim+active passed gradient checking!
#              transition:I-art+B-tim+debt passed gradient checking!
#        transition:B-geo+I-art+university passed gradient checking!
#        transition:B-art+B-art+Bouteflika passed gradient checking!
#        transition:B-tim+I-art+additional passed gradient checking!
#             transition:B-geo+I-art+Carla passed gradient checking!
#        transition:B-per+I-geo+protesting passed gradient checking!
#          transition:I-eve+B-per+outcries passed gradient checking!
#                transition:B-per+O+letter passed gradient checking!
#               transition:I-per+I-art+148 passed gradient checking!
#               transition:B-geo+I-org+try passed gradient checking!
#     transition:B-nat+I-per+environmental passed gradient checking!
#              transition:B-org+B-geo+high passed gradient checking!
#               transition:I-geo+I-art+led passed gradient checking!
#             transition:B-eve+I-tim+Sport passed gradient checking!
#            transition:I-per+B-nat+itself passed gradient checking!
#            transition:I-gpe+I-art+rocket passed gradient checking!
#               transition:B-geo+I-org+HIV passed gradient checking!
#        transition:I-geo+I-art+subsurface passed gradient checking!
#              transition:I-geo+I-geo+Wali passed gradient checking!
#     transition:B-tim+I-geo+mathematician passed gradient checking!
#          transition:B-tim+B-org+defended passed gradient checking!
#              transition:B-per+B-nat+NATO passed gradient checking!
#          transition:I-per+B-org+autonomy passed gradient checking!
#          transition:I-tim+B-geo+dividing passed gradient checking!
#          transition:I-per+I-per+homeland passed gradient checking!
#                 emission:B-org+Gabcikovo passed gradient checking!
#           transition:I-tim+I-geo+Senator passed gradient checking!
#     transition:I-tim+I-org+assassination passed gradient checking!
#           transition:I-eve+I-eve+Moammar passed gradient checking!
#               transition:O+B-org+private passed gradient checking!
#              transition:B-geo+B-org+drug passed gradient checking!
#            transition:B-org+B-tim+locked passed gradient checking!
#                 transition:O+O+directors didnot pass gradient checking!
#         transition:B-tim+I-gpe+nightclub passed gradient checking!
#     transition:B-tim+I-org+privatization passed gradient checking!
#            transition:I-org+B-org+though passed gradient checking!
#             transition:START+O+Junichiro passed gradient checking!
#            transition:B-org+B-eve+agents passed gradient checking!
#            transition:START+I-art+Hadley passed gradient checking!
#            transition:I-gpe+B-art+Barack passed gradient checking!
#          transition:START+B-per+recently passed gradient checking!
#             transition:I-org+B-eve+happy passed gradient checking!
#             transition:B-eve+B-eve+storm passed gradient checking!
#                   emission:I-eve+refused passed gradient checking!
#             transition:B-tim+B-tim+video passed gradient checking!
#         transition:B-tim+B-per+determine passed gradient checking!
#            transition:B-nat+B-eve+Marine passed gradient checking!
#             transition:I-per+B-nat+great passed gradient checking!
#             transition:B-per+B-per+Yanbu passed gradient checking!
#                     transition:O+O+wound passed gradient checking!
#                    transition:O+B-org+60 passed gradient checking!
#                transition:B-nat+I-org+46 passed gradient checking!
#               transition:I-art+I-art+CAR passed gradient checking!
#                 transition:O+I-gpe+along passed gradient checking!
#             transition:B-eve+B-per+drove passed gradient checking!
#         transition:I-eve+I-eve+employees passed gradient checking!
#      transition:B-geo+B-gpe+perpetrators passed gradient checking!
#          transition:B-art+B-eve+detainee passed gradient checking!
#       transition:I-tim+B-nat+possibility passed gradient checking!
#         transition:I-org+B-nat+Kujundzic passed gradient checking!
#           transition:B-tim+I-geo+Bangkok passed gradient checking!
#             transition:O+B-art+Marseille passed gradient checking!
#    transition:I-tim+I-gpe+anti-terrorism passed gradient checking!
#              transition:I-geo+I-gpe+teen passed gradient checking!
#           transition:I-org+B-geo+Cleland passed gradient checking!
#         transition:B-nat+B-gpe+Ethiopian passed gradient checking!
#              transition:B-nat+B-org+only passed gradient checking!
#            transition:B-geo+B-art+policy passed gradient checking!
# ...
#           transition:I-tim+I-art+Shi'ite passed gradient checking!
#           transition:I-art+I-org+pumping passed gradient checking!
#        transition:B-art+I-gpe+particular passed gradient checking!
#             transition:I-geo+B-nat+those passed gradient checking!
#              transition:B-tim+I-per+debt passed gradient checking!
#                 transition:B-geo+I-geo+' passed gradient checking!
#             transition:I-geo+B-nat+1,247 passed gradient checking!
#             transition:B-geo+I-per+Major passed gradient checking!
#               transition:B-tim+B-eve+our passed gradient checking!
#            transition:B-nat+I-org+spread passed gradient checking!
#            transition:B-gpe+I-org+Vidoje passed gradient checking!
#          transition:I-gpe+B-tim+accident passed gradient checking!
#              transition:B-gpe+I-art+1942 passed gradient checking!
#      transition:B-per+B-tim+relationship passed gradient checking!
#          transition:I-eve+B-gpe+district passed gradient checking!
#       transition:I-org+B-gpe+Condoleezza passed gradient checking!
#              transition:B-per+B-org+Mars passed gradient checking!
#            transition:B-tim+B-art+rubble passed gradient checking!
#        transition:B-gpe+B-nat+complained passed gradient checking!
#           transition:I-tim+I-per+receive passed gradient checking!
#          transition:B-eve+I-geo+surprise passed gradient checking!
#               transition:B-per+B-geo+100 passed gradient checking!
#        transition:I-gpe+I-art+Lieutenant passed gradient checking!
#          transition:B-org+B-per+baseless passed gradient checking!
#    transition:B-tim+B-per+responsibility passed gradient checking!
#         transition:B-org+B-geo+Zapatista passed gradient checking!
#            transition:I-org+I-eve+filmed passed gradient checking!
#           transition:B-gpe+B-eve+Council passed gradient checking!
#           transition:I-gpe+B-art+medical passed gradient checking!
#                transition:B-gpe+O+Strobl passed gradient checking!
#            transition:B-eve+I-geo+Quagga passed gradient checking!
#             transition:I-per+I-tim+CONTE passed gradient checking!
#           transition:B-org+I-per+bowlers passed gradient checking!
#           transition:B-geo+B-eve+16-stop passed gradient checking!
#            transition:B-geo+I-gpe+Mehlis passed gradient checking!
#           transition:I-geo+B-eve+Pohamba passed gradient checking!
#           transition:B-gpe+I-eve+minutes passed gradient checking!
#               transition:O+B-eve+limited passed gradient checking!
#                transition:I-geo+O+supply passed gradient checking!
#                   transition:B-eve+O+del passed gradient checking!
#            transition:B-per+I-eve+sought passed gradient checking!
#         transition:B-gpe+B-tim+belonging passed gradient checking!
#            transition:I-gpe+I-eve+voters passed gradient checking!
#              transition:I-geo+B-geo+City passed gradient checking!
#                  transition:O+B-nat+case passed gradient checking!
#           transition:I-org+B-per+singles passed gradient checking!
#              transition:START+O+hospital passed gradient checking!
#    transition:B-nat+B-per+redistribution passed gradient checking!
#          transition:B-nat+B-org+ambushed passed gradient checking!
#              transition:B-geo+I-art+Phau passed gradient checking!
#          transition:START+B-geo+positive passed gradient checking!
#               transition:I-tim+B-tim+war passed gradient checking!
#             transition:B-tim+I-tim+young passed gradient checking!
#             transition:I-org+O+turbulent passed gradient checking!
#           transition:B-nat+B-tim+Baltica passed gradient checking!
#            transition:B-org+I-eve+cities passed gradient checking!
#                    emission:I-tim+having passed gradient checking!
#            transition:I-eve+I-gpe+spinal passed gradient checking!
#             transition:B-org+I-eve+Denis passed gradient checking!
#                  emission:B-gpe+succeeds passed gradient checking!
#              transition:B-per+B-nat+near passed gradient checking!
#        transition:B-nat+B-geo+explosives passed gradient checking!
#         transition:I-tim+I-per+defaulted passed gradient checking!
#                transition:B-geo+O+states passed gradient checking!
#           transition:B-per+B-eve+untaxed passed gradient checking!
#         transition:B-gpe+B-nat+consulate passed gradient checking!
#         transition:I-gpe+B-gpe+influenza passed gradient checking!
#         transition:B-nat+B-geo+activists passed gradient checking!
#                   transition:O+B-per+aid passed gradient checking!
#       transition:B-art+I-per+maintenance passed gradient checking!
#           transition:B-org+B-gpe+spotted passed gradient checking!
#              transition:I-eve+I-geo+step passed gradient checking!
#              transition:B-nat+I-eve+Rice passed gradient checking!
#             transition:I-org+B-eve+drawn passed gradient checking!
#                emission:I-geo+operations passed gradient checking!
#           transition:START+B-geo+greatly passed gradient checking!
#                         emission:B-per+5 passed gradient checking!
#           transition:I-gpe+B-per+exports passed gradient checking!
#                   emission:I-geo+network passed gradient checking!
#            transition:B-per+B-tim+Zidane passed gradient checking!
#           transition:START+I-org+Hungary passed gradient checking!
#            transition:START+I-art+lasted passed gradient checking!
#        transition:I-eve+B-eve+automotive passed gradient checking!
#                emission:B-org+airstrikes passed gradient checking!
#              transition:B-art+B-eve+date passed gradient checking!
#           transition:I-per+I-art+Laurent passed gradient checking!
#            transition:B-geo+I-eve+advice passed gradient checking!
#          transition:I-eve+B-nat+entrance passed gradient checking!
#           transition:START+B-art+message passed gradient checking!
#             transition:START+B-nat+leads passed gradient checking!
#                emission:I-art+parliament passed gradient checking!
#         transition:I-per+B-per+kidnapped passed gradient checking!
#         transition:B-org+I-art+blessings passed gradient checking!
#           transition:I-per+B-per+ordered passed gradient checking!
#       transition:I-gpe+B-nat+22-year-old passed gradient checking!
#                 emission:B-art+Islamists passed gradient checking!
#         transition:B-nat+I-tim+Moroccans passed gradient checking!
#             transition:I-geo+B-per+small passed gradient checking!
#              transition:B-geo+B-nat+tied passed gradient checking!
#              transition:START+B-gpe+noon passed gradient checking!
#             transition:START+B-nat+along passed gradient checking!
#              transition:I-eve+B-geo+into passed gradient checking!
#             transition:B-geo+B-eve+quick passed gradient checking!
#           transition:B-art+I-tim+Between passed gradient checking!
#           transition:START+B-per+Youssef passed gradient checking!
#              transition:START+I-per+wide passed gradient checking!
#              transition:I-org+B-tim+runs passed gradient checking!
#             transition:B-art+B-gpe+arson passed gradient checking!
#               transition:B-org+B-tim+GDP passed gradient checking!
#         transition:I-geo+I-art+contracts passed gradient checking!
#               transition:O+I-eve+Islamic passed gradient checking!
#            transition:I-art+I-org+caught passed gradient checking!
#          transition:I-art+B-gpe+Nahrawan passed gradient checking!
#             transition:O+I-org+sustained passed gradient checking!
#          transition:B-eve+B-art+homeland passed gradient checking!
#            transition:B-nat+B-per+Boldak passed gradient checking!
#          transition:I-geo+B-tim+deadlock passed gradient checking!
#             transition:I-eve+B-art+drugs passed gradient checking!
#              transition:I-tim+I-tim+More passed gradient checking!
#           transition:I-eve+I-art+Chalabi passed gradient checking!
#             transition:B-per+I-gpe+Simon passed gradient checking!
#         transition:I-gpe+I-org+Hollywood passed gradient checking!
#    transition:B-gpe+I-per+energy-related passed gradient checking!
#            transition:I-geo+B-tim+coping passed gradient checking!
#                 transition:B-eve+O+stage passed gradient checking!
#                 transition:B-eve+B-gpe+I passed gradient checking!
#             transition:B-eve+I-tim+clear passed gradient checking!
#         transition:B-art+I-gpe+skeptical passed gradient checking!
#                    transition:B-eve+O+no passed gradient checking!
#         transition:B-nat+B-tim+nationals passed gradient checking!
#        transition:I-tim+I-org+commanders passed gradient checking!
#           transition:B-per+B-gpe+Marines passed gradient checking!
#                   emission:I-eve+actions passed gradient checking!
#             transition:I-eve+I-eve+Cimpl passed gradient checking!
#               transition:B-org+B-geo+job passed gradient checking!
#               transition:B-geo+I-geo+Day passed gradient checking!
#              transition:I-eve+I-tim+most passed gradient checking!
#                transition:O+B-geo+Hadley passed gradient checking!
#        transition:START+I-org+occasional passed gradient checking!
#        transition:I-geo+B-nat+Goalkeeper passed gradient checking!
#         transition:B-per+B-gpe+Mogadishu passed gradient checking!
#            transition:B-tim+I-org+packed passed gradient checking!
#                       emission:I-eve+Lee passed gradient checking!
#              transition:B-gpe+B-per+lift passed gradient checking!
#            transition:B-tim+I-geo+Hadley passed gradient checking!
#        transition:B-eve+B-art+Guggenheim passed gradient checking!
#             transition:B-eve+B-org+Irish passed gradient checking!
#         transition:I-gpe+B-per+terrorist passed gradient checking!
#             transition:I-art+B-eve+years passed gradient checking!
#           transition:B-art+I-art+develop passed gradient checking!
#      transition:B-geo+B-gpe+self-imposed passed gradient checking!
#         transition:B-eve+B-art+financial passed gradient checking!
#            transition:I-gpe+B-art+Chiefs passed gradient checking!
#           transition:I-geo+B-art+someone passed gradient checking!
#             transition:I-org+I-org+ahead passed gradient checking!
#            transition:I-per+B-geo+bribes passed gradient checking!
#              transition:O+B-geo+separate passed gradient checking!
#          transition:START+B-eve+fighting passed gradient checking!
#             transition:I-art+I-org+press passed gradient checking!
#         transition:I-eve+B-geo+insulting passed gradient checking!
#              transition:B-tim+I-org+King passed gradient checking!
#                  transition:O+B-eve+Alps passed gradient checking!
#           transition:I-geo+B-org+Laurent passed gradient checking!
#                 transition:O+B-nat+dying passed gradient checking!
#           transition:I-org+B-per+Germany passed gradient checking!
#          transition:I-art+I-org+outlawed passed gradient checking!
#               transition:B-art+B-tim+lay passed gradient checking!
#            transition:B-per+B-gpe+second passed gradient checking!
#         transition:B-tim+I-tim+Important passed gradient checking!
#                     emission:I-per+areas passed gradient checking!
#    transition:B-org+B-art+Representative passed gradient checking!
#              transition:B-geo+B-per+west passed gradient checking!
#             transition:B-nat+B-art+ninth passed gradient checking!
#            transition:B-geo+I-eve+Rights passed gradient checking!
#              transition:O+B-eve+military passed gradient checking!
#                transition:I-gpe+O+houses passed gradient checking!
#            transition:B-nat+I-per+Cubans passed gradient checking!
#          transition:B-tim+B-tim+grueling passed gradient checking!
#             transition:I-gpe+B-gpe+slick passed gradient checking!
#                transition:I-gpe+I-eve+17 passed gradient checking!
#     transition:B-org+B-per+authenticated passed gradient checking!
#      transition:B-geo+I-art+nonpermanent passed gradient checking!
#            transition:I-per+B-eve+Turkey passed gradient checking!
#       transition:I-per+I-eve+threatening passed gradient checking!
#          transition:I-geo+B-geo+genocide passed gradient checking!
#            transition:I-art+B-gpe+cartel passed gradient checking!
#               transition:I-per+O+advisor passed gradient checking!
#             transition:START+B-tim+labor passed gradient checking!
#         transition:B-nat+I-art+Nangarhar passed gradient checking!
#              transition:I-eve+B-geo+ship passed gradient checking!
#               transition:START+B-geo+how passed gradient checking!
#            transition:I-org+I-per+behind passed gradient checking!
#        transition:I-gpe+I-org+Democratic passed gradient checking!
#      transition:I-geo+B-org+anti-Taliban passed gradient checking!
#         transition:B-art+B-eve+prisoners passed gradient checking!
#               transition:I-tim+I-eve+the passed gradient checking!
#          transition:I-tim+I-art+grouping passed gradient checking!
#                transition:B-org+B-org+14 passed gradient checking!
#          transition:B-geo+I-org+Bordeaux passed gradient checking!
#           transition:B-gpe+B-art+dispute passed gradient checking!
#          transition:B-eve+I-art+position passed gradient checking!
#               transition:B-nat+I-geo+Are passed gradient checking!
#           transition:I-art+B-nat+Russian passed gradient checking!
#             transition:B-eve+I-gpe+years passed gradient checking!
#             transition:I-tim+B-tim+anger passed gradient checking!
#         transition:I-per+I-per+terrorist passed gradient checking!
#            transition:START+B-geo+40-car passed gradient checking!
#              transition:B-nat+I-eve+peat passed gradient checking!
#             transition:I-tim+B-org+along passed gradient checking!
#           transition:I-org+I-org+benzene passed gradient checking!
#            transition:B-nat+I-eve+church passed gradient checking!
#          transition:B-per+I-tim+welcomed passed gradient checking!
#          transition:I-tim+I-org+Delivery passed gradient checking!
#              transition:I-geo+I-tim+They passed gradient checking!
#         transition:B-geo+I-per+gathering passed gradient checking!
#           transition:I-org+B-nat+Between passed gradient checking!
#           transition:B-per+I-geo+waivers passed gradient checking!
#        transition:B-art+I-eve+protesting passed gradient checking!
#                 transition:B-art+O+fewer passed gradient checking!
#           transition:I-tim+I-geo+Believe passed gradient checking!
#              transition:B-gpe+B-per+when passed gradient checking!
#            transition:B-eve+I-per+passes passed gradient checking!
#          transition:I-per+I-per+received passed gradient checking!
#          transition:B-art+O+Institutions passed gradient checking!
#            transition:START+B-nat+margin passed gradient checking!
#          transition:B-org+I-gpe+unlikely passed gradient checking!
#           transition:B-org+I-art+tougher passed gradient checking!
#                      emission:B-art+goes passed gradient checking!
#             transition:B-nat+I-art+signs passed gradient checking!
#        transition:I-art+I-gpe+considered passed gradient checking!
#          transition:B-org+B-org+Federico passed gradient checking!
#             transition:B-geo+B-tim+equal passed gradient checking!
#         transition:I-gpe+I-per+Hollywood passed gradient checking!
#              transition:B-geo+B-nat+week passed gradient checking!
#              transition:I-eve+I-eve+foot passed gradient checking!
#          transition:I-art+B-org+response passed gradient checking!
#             transition:B-nat+B-art+Brig. passed gradient checking!
#            transition:B-org+I-per+Somali passed gradient checking!
